# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanshita613/python-practice/blob/main/pract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter a number:"))
b=int(input("enter second number:"))

sum=a+b
print(sum)
# Out:
# enter a number:67
# enter second number:44
# 111

# %%
import pandas as pd

list=[1,2,3,57,7]
var=pd.DataFrame(list)
print(var)
# Out:
#     0
# 0   1
# 1   2
# 2   3
# 3  57
# 4   7

# %%
dict={ "num":[2,3,5,7] , "num2":[2,7,2,9]}

var1=pd.DataFrame(dict,columns=["num2"])
print(var1)
print(type(var1))
# Out:
#    num2
# 0     2
# 1     7
# 2     2
# 3     9
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# **CSV FILE**

# %%
info={"name":[1,2,3,4] , "num":[5,6,7,4]}

var = pd.DataFrame(info)

print(info)
print(type(info))

var.to_csv("test_csv")
# Out:
# {'name': [1, 2, 3, 4], 'num': [5, 6, 7, 4]}
# <class 'dict'>

# %%
pd.read_csv("file.csv")
